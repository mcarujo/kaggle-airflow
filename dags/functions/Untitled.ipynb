# %%
"""
Helper file for kaggle_imovirtual DAG.
"""

import logging
import os
import re
import shutil
import time
from joblib import Parallel, delayed

import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

logging.getLogger().setLevel(logging.INFO)

# %%
def get_info_from_article(article: BeautifulSoup) -> dict:
    """
    Receive a soup object and html then return in a dict the data.

    Args:
        article (BeautifulSoup): soup object that contains the ads html.

    Returns:
        dict: information related to the announcement.
    """

    residence = dict()
    residence["local"] = article.find("p", class_="text-nowrap").text.split(":")[1]

    residence["rooms"] = article.find("li", class_="offer-item-rooms hidden-xs").text

    residence["price"] = article.find("li", class_="offer-item-price").text
    residence["price"] = re.sub("[^0-9]", "", residence["price"])

    residence["area"] = article.find("li", class_="hidden-xs offer-item-area").text
    residence["area"] = re.sub("[m² ]", "", residence["area"])

    try:
        aux = [
            li.text
            for li in article.find("ul", class_="parameters-view hidden-xs").find_all(
                "li"
            )
        ]

    except:
        aux = [
            li.text
            for li in article.find(
                "ul", class_="params-small clearfix hidden-xs"
            ).find_all("li")
        ]
    try:
        residence["restroom"] = re.sub("[^0-9]", "", aux[0])
    except:
        residence["restroom"] = None

    try:
        residence["status"] = aux[1]
    except:
        residence["status"] = np.nan

    return residence


def get_info_from_page(soup: BeautifulSoup) -> list:
    """Create a list of ads for each page.

    Args:
        soup (BeautifulSoup): html of a page that contains a list of ads.

    Returns:
        list: returns a list of dict with the ad information.
    """
    articles = soup.find_all("article")
    aux = []
    for index, article in enumerate(articles):
        try:
            aux.append(get_info_from_article(article))
        except:
            logging.info("Error to get article index %s", index)
    return aux


def get_regions():
    """
    Store the Regions of Portugal and the directly ID.

    Returns:
        list:tuple: return a list of tuples for Region and Region id.
    """
    return [
        ("Aveiro", "1"),
        ("Beja", "2"),
        ("Braga", "3"),
        ("Bragança", "4"),
        ("Castelo Branco", "5"),
        ("Coimbra", "6"),
        ("Évora", "7"),
        ("Faro", "8"),
        ("Guarda", "9"),
        ("Ilha da Graciosa", "24"),
        ("Ilha da Madeira", "19"),
        ("Ilha das Flores", "28"),
        ("Ilha de Porto Santo", "20"),
        ("Ilha de Santa Maria", "21"),
        ("Ilha de São Jorge", "25"),
        ("Ilha de São Miguel", "22"),
        ("Ilha do Corvo", "29"),
        ("Ilha do Faial", "27"),
        ("Ilha do Pico", "26"),
        ("Ilha Terceira", "23"),
        ("Leiria", "10"),
        ("Lisboa", "11"),
        ("Portalegre", "12"),
        ("Porto", "13"),
        ("Santarém", "14"),
        ("Setúbal", "15"),
        ("Viana do Castelo", "16"),
        ("Vila Real", "17"),
        ("Viseu", "18"),
    ]


def create_request_link(service_type, residence_type, region, page):
    space = " "
    dash = "-"
    return f"https://www.imovirtual.com/{service_type}/{residence_type}"\
        + f"/{region[0].lower().replace(space,dash)}"\
        + f"/?search%5Bregion_id%5D={region[1]}&nrAdsPerPage=72&page={page}"
        
def get_html_as_bs(
    region: tuple, page: str, service_type: str, residence_type: str
) -> BeautifulSoup:
    """
    Execute a request to the website then use the html to instantiate a BeautifulSoup object.

    Args:
        region (tuple): region of Portugal used in the search.
        page (str): searched page.
        service_type (str): determine what service the residence belongs.
        residence_type (str): the type of residence, covered so far by house or apartment.

    Returns:
        BeautifulSoup: a BeautifulSoup object made using the html requested.
    """

    response = requests.get(create_request_link(service_type, residence_type, region, page),timeout=120,
    )
    return BeautifulSoup(response.text, features="lxml")


def serialize_extraction(output_path_folder: str) -> None:
    """
    Start the data extraction process based on residence and service type.

    Args:
        output_path_folder (str): path to store the partial csv.
    """
    for residence_type in ["moradia", "apartamento"]:  # house or apartment
        for service_type in ["arrendar", "comprar", "ferias"]:  # rent, buy or vacation
            extract_by_type(service_type, residence_type, output_path_folder)




def create_output_path(output_path: str):
    """
    Function to create the output if not exists.

    Args:
        output_path (str): output folder name.
    """
    if os.path.exists(output_path):
        logging.info(
            "The output path '%s' already exists, so let's clean...", output_path
        )
        shutil.rmtree(output_path)

    os.makedirs(output_path)
    logging.info("The output path '%s' has been created empty.", output_path)


def format_transform_consolidate(output_path: str, file_name: str) -> None:
    """Load all partials csv into one, format it and then store it.

    Args:
        output_path (str): path to store the final csv.
        file_name (str): name for the final csv.

    Returns:
        None: no return.
    """
    paths_df = []
    for residence_type in ["moradia", "apartamento"]:  # house or apartment
        for service_type in ["arrendar", "comprar", "ferias"]:  # rent, buy or vacation
            paths_df.append(
                os.path.join(output_path, f"{service_type}_{residence_type}.csv")
            )
    list_df = pd.concat(paths_df)

    list_df.columns = [
        "Location",
        "Rooms",
        "Price",
        "Area",
        "Bathrooms",
        "Condition",
        "AdsType",
        "ProprietyType",
    ]
    list_df.Price = list_df.Price.apply(float).round(2)
    list_df.Rooms = list_df.Rooms.apply(lambda x: x.replace("T", ""))

    def format_bathrooms(quantity_bathrooms):
        try:
            bathrooms = int(quantity_bathrooms)
            if bathrooms > 100:
                return np.nan
            return bathrooms
        except:
            return np.nan

    list_df.Bathrooms = list_df.Bathrooms.apply(format_bathrooms)

    list_df.Rooms = list_df.Rooms.apply(lambda x: x.replace("T", ""))
    list_df.Condition = list_df.Condition.map(
        {
            "Ruína": "In ruin",
            "Novo": "New",
            "Renovado": "Renovated",
            "Usado": "Used",
            "Em construção": "Under construction",
            "Para recuperar": "To recovery",
        }
    )
    list_df.AdsType = list_df.AdsType.map(
        {
            "arrendar": "Rent",
            "ferias": "Vacation",
            "comprar": "Sell",
        }
    )
    list_df.ProprietyType = list_df.ProprietyType.map(
        {
            "apartamento": "Apartment",
            "moradia": "House",
        }
    )
    list_df.Area = list_df.Area.str.replace(",", ".").apply(float).round(2)
    list_df.dropna()
    list_df.to_csv(os.path.join(output_path, file_name), index=False)
    paths_df = [os.remove(os.path.join(output_path, path_df)) for path_df in paths_df]

     


def pre_extract_by_type(
time_sleep: int = 1
) -> None:
    """
    Extract the data from imovirtual page based on service and residence type
    then store a DataFrame in the output folder specified.

    Args:
        service_type (str): determine what service the residence belongs.
        residence_type (str): the type of residence, covered so far by house or apartment.
        output_path (str): the DataFrame destination.
        time_sleep (int): seconds to wait between requests.

    Returns:
        None: the goal is just store in the output folder.
    """
    logging.info(
        "Started pre extract database!"
    )
    pages = []
    regions = get_regions()
    residences  = ["moradia", "apartamento"] # house or apartment
    services  = ["arrendar", "comprar", "ferias"]# rent, buy or vacation

    for residence_type in residences:  
        for service_type in services:  
            for region in regions:
                time.sleep(time_sleep)
                n_offers, max_pages = get_number_of_pages(
                    get_html_as_bs(region, "1", service_type, residence_type)
                )
                logging.info(
                    "Total of %s pages (offers: %s) for the %s region considering %s - %s.",
                    max_pages,
                    n_offers,
                    region[0],
                    service_type,
                    residence_type,
                )
                for page in range(1, max_pages + 1):
                    aux_dict={'page':page,'region':region, 'max_pages':max_pages,'n_offers':n_offers,'service_type':service_type,'residence_type':residence_type,'flag_extract':False}
                    pages.append(aux_dict)

                    
        pages_df  = pd.DataFrame(pages)
        pages_df_filter = pages_df.n_offers != 0
        return pages_df[pages_df_filter]

def get_number_of_pages(soup: BeautifulSoup) -> int:
    """
    Catch the information of how many pages of ad for that area.

    Args:
        soup (BeautifulSoup): soup object that contains the html.

    Returns:
        int: The number of pages, in case of issue returns 1.
    """
    try:
        n_offers = int(soup.find('div', class_="offers-index pull-left text-nowrap").find('strong').text.replace(' ','').replace('\n',''))
    except:
        n_offers = 0
    try:
        n_pages = int(soup.find("ul", class_="pager").find_all("li")[-2].text)
    except:
        n_pages = 1
        
    return n_offers, n_pages

# %%
list_pages = pre_extract_by_type()
# Out:
# INFO:root:Started pre extract database!
# INFO:root:Total of 1 pages (offers: 13) for the Aveiro region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 6) for the Beja region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 32) for the Braga region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Bragança region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 8) for the Castelo Branco region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 9) for the Coimbra region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 8) for the Évora region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 60) for the Faro region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Guarda region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Ilha da Graciosa region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 8) for the Ilha da Madeira region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha das Flores region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de Porto Santo region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de Santa Maria region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de São Jorge region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de São Miguel region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha do Corvo region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Ilha do Faial region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha do Pico region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha Terceira region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 24) for the Leiria region considering arrendar - moradia.
# INFO:root:Total of 3 pages (offers: 170) for the Lisboa region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 4) for the Portalegre region considering arrendar - moradia.
# INFO:root:Total of 2 pages (offers: 86) for the Porto region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 13) for the Santarém region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 63) for the Setúbal region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 7) for the Viana do Castelo region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 9) for the Vila Real region considering arrendar - moradia.
# INFO:root:Total of 1 pages (offers: 10) for the Viseu region considering arrendar - moradia.
# INFO:root:Total of 57 pages (offers: 4103) for the Aveiro region considering comprar - moradia.
# INFO:root:Total of 13 pages (offers: 907) for the Beja region considering comprar - moradia.
# INFO:root:Total of 78 pages (offers: 5588) for the Braga region considering comprar - moradia.
# INFO:root:Total of 6 pages (offers: 391) for the Bragança region considering comprar - moradia.
# INFO:root:Total of 17 pages (offers: 1206) for the Castelo Branco region considering comprar - moradia.
# INFO:root:Total of 39 pages (offers: 2744) for the Coimbra region considering comprar - moradia.
# INFO:root:Total of 12 pages (offers: 809) for the Évora region considering comprar - moradia.
# INFO:root:Total of 82 pages (offers: 5863) for the Faro region considering comprar - moradia.
# INFO:root:Total of 9 pages (offers: 637) for the Guarda region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 12) for the Ilha da Graciosa region considering comprar - moradia.
# INFO:root:Total of 15 pages (offers: 1079) for the Ilha da Madeira region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 19) for the Ilha das Flores region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 30) for the Ilha de Porto Santo region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 49) for the Ilha de Santa Maria region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 27) for the Ilha de São Jorge region considering comprar - moradia.
# INFO:root:Total of 11 pages (offers: 788) for the Ilha de São Miguel region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 2) for the Ilha do Corvo region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 56) for the Ilha do Faial region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 67) for the Ilha do Pico region considering comprar - moradia.
# INFO:root:Total of 4 pages (offers: 275) for the Ilha Terceira region considering comprar - moradia.
# INFO:root:Total of 48 pages (offers: 3454) for the Leiria region considering comprar - moradia.
# INFO:root:Total of 101 pages (offers: 7248) for the Lisboa region considering comprar - moradia.
# INFO:root:Total of 9 pages (offers: 616) for the Portalegre region considering comprar - moradia.
# INFO:root:Total of 127 pages (offers: 9077) for the Porto region considering comprar - moradia.
# INFO:root:Total of 50 pages (offers: 3561) for the Santarém region considering comprar - moradia.
# INFO:root:Total of 85 pages (offers: 6114) for the Setúbal region considering comprar - moradia.
# INFO:root:Total of 29 pages (offers: 2021) for the Viana do Castelo region considering comprar - moradia.
# INFO:root:Total of 12 pages (offers: 813) for the Vila Real region considering comprar - moradia.
# INFO:root:Total of 17 pages (offers: 1186) for the Viseu region considering comprar - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Aveiro region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Beja region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 12) for the Braga region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Bragança region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Castelo Branco region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 2) for the Coimbra region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Évora region considering ferias - moradia.
# INFO:root:Total of 4 pages (offers: 260) for the Faro region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Guarda region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha da Graciosa region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha da Madeira region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha das Flores region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de Porto Santo region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de Santa Maria region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de São Jorge region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha de São Miguel region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha do Corvo region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha do Faial region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha do Pico region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Ilha Terceira region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 5) for the Leiria region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 4) for the Lisboa region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Portalegre region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 4) for the Porto region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Santarém region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Setúbal region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 6) for the Viana do Castelo region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 0) for the Vila Real region considering ferias - moradia.
# INFO:root:Total of 1 pages (offers: 1) for the Viseu region considering ferias - moradia.

# %%
list_pages['flag_extract'] = False
count_try = 0
still_open = True
break_time = 10

list_pages
# Out:
#      page                  region  max_pages  n_offers service_type  \
# 0       1             (Aveiro, 1)          1        13     arrendar
# 1       1               (Beja, 2)          1         6     arrendar
# 2       1              (Braga, 3)          1        32     arrendar
# 3       1           (Bragança, 4)          1         1     arrendar
# 4       1     (Castelo Branco, 5)          1         8     arrendar
# ..    ...                     ...        ...       ...          ...
# 887     1             (Porto, 13)          1         4       ferias
# 888     1          (Santarém, 14)          1         1       ferias
# 889     1           (Setúbal, 15)          1         1       ferias
# 890     1  (Viana do Castelo, 16)          1         6       ferias
# 892     1             (Viseu, 18)          1         1       ferias
#
#     residence_type  flag_extract
# 0          moradia         False
# 1          moradia         False
# 2          moradia         False
# 3          moradia         False
# 4          moradia         False
# ..             ...           ...
# 887        moradia         False
# 888        moradia         False
# 889        moradia         False
# 890        moradia         False
# 892        moradia         False
#
# [868 rows x 7 columns]

# %%
def get_info_pre_page(page):
    page_dict = dict(page)
    if page_dict['flag_extract'] == False:
        try:
            html = get_html_as_bs(page_dict['region'], page_dict['page'], page_dict['service_type'], page_dict['residence_type'])
            return_info= get_info_from_page(html)
            return return_info if return_info else False
        except:
            return False
    else:
        return page_dict['flag_extract']

# %%
count_try = 0

# %%
print('Starting while.')
while count_try < 1 and still_open:       
    aux_list = Parallel(n_jobs=2, backend="threading", verbose=10)(
            delayed(get_info_pre_page)(page) for i, page in list_pages.iterrows()
        )
    
    list_pages['flag_extract'] = aux_list
    
    count_try += 1
    n_left = sum(list_pages.flag_extract == False)
    print('How many are left?',n_left )
    if n_left == 0:
        still_open = False

    print('count_try', count_try)
    print('still_open', still_open)
    
    print(f'Waiting {break_time} Seconds.')
    time.sleep(break_time)
# Out:
# Starting while.
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=2)]: Done  14 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:   12.8s
# INFO:root:Error to get article index 0
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=2)]: Done  37 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=2)]: Done  57 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=2)]: Done  68 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=2)]: Done  81 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done 109 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done 124 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=2)]: Done 141 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=2)]: Done 158 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=2)]: Done 177 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=2)]: Done 217 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=2)]: Done 238 tasks      | elapsed:  3.1min
# INFO:root:Error to get article index 12
# INFO:root:Error to get article index 14
# [Parallel(n_jobs=2)]: Done 261 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=2)]: Done 284 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=2)]: Done 309 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=2)]: Done 334 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=2)]: Done 361 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=2)]: Done 388 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=2)]: Done 417 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=2)]: Done 477 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=2)]: Done 508 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=2)]: Done 541 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=2)]: Done 574 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=2)]: Done 609 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=2)]: Done 644 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=2)]: Done 681 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=2)]: Done 718 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=2)]: Done 757 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=2)]: Done 796 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=2)]: Done 837 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=2)]: Done 868 out of 868 | elapsed:  4.7min finished
# How many are left? 616
# count_try 1
# still_open True
# Waiting 10 Seconds.

# %%
list_pages.flag_extract[650:]
# Out:
# C:\Users\MARCO_~1\AppData\Local\Temp/ipykernel_21288/3418149642.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   list_pages.flag_extract[650:]
# 658    False
# 659    False
# 660    False
# 661    False
# 662    False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 892    False
# Name: flag_extract, Length: 218, dtype: object
